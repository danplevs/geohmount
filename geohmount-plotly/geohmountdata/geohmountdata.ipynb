# %%
# importando as bibliotecas
import pandas as pd

# importando e visualizando os dados 
df = pd.read_excel('geohmountdata.xlsx')
df.head()
# Out:
#     Ponto     Tipo   Amostras Data da coleta  Dias de chuva      pH  \
# 0     NaN      NaN        NaN            NaT            NaN     NaN
# 1  Bonfim  Fluvial   BM180505     2018-05-05            NaN  5.5820
# 2  Bonfim  Fluvial   BM180526     2018-05-26            NaN  5.9600
# 3  Bonfim  Fluvial   BM180629     2018-06-29            NaN  6.7250
# 4  Bonfim  Fluvial  BM180731      2018-07-31            NaN  6.5155
#
#   Condutividade Altura de chuva   Vazão   Temperatura  ...           V  \
# 0       uS cm-1              dm  m3 s-1    ̊C          ...          µM
# 1           6.9             NaN    0.18          14.9  ...  0.00242042
# 2           6.6             NaN    0.14          13.1  ...  0.00275178
# 3           7.2             NaN    0.09          12.5  ...  0.00176673
# 4           7.8             NaN    0.06          13.6  ...  0.00163148
#
#            Zn          La          Ce           Pr           Sm           Eu  \
# 0          µM          µM          µM           µM           µM           µM
# 1  0.00214987  0.00157373  0.00269569  0.000334545  0.000117185  2.46111e-05
# 2   0.0432083  0.00197249  0.00295798  0.000417011  0.000207502  2.67827e-05
# 3   0.0393545   0.0016486  0.00254075  0.000333552  0.000226124   2.6322e-05
# 4  0.00214987  0.00121241  0.00175433  0.000279687  8.55281e-05  1.78332e-05
#
#             Gd       Nd          Pb
# 0           µM      ppb         ppb
# 1  0.000118092  0.24932     0.04425
# 2  0.000214372  0.20307     0.05465
# 3  0.000146264     0.18  0.00644777
# 4  0.000120763  0.13043  0.00644777
#
# [5 rows x 69 columns]

# %%
# excluindo a primeira linha
df = df.drop(0)

# definindo 'amostras' como índice
df.head()
# Out:
#     Ponto     Tipo   Amostras Data da coleta  Dias de chuva      pH  \
# 1  Bonfim  Fluvial   BM180505     2018-05-05            NaN  5.5820
# 2  Bonfim  Fluvial   BM180526     2018-05-26            NaN  5.9600
# 3  Bonfim  Fluvial   BM180629     2018-06-29            NaN  6.7250
# 4  Bonfim  Fluvial  BM180731      2018-07-31            NaN  6.5155
# 5  Bonfim  Fluvial   BM180831     2018-08-31            NaN  6.8160
#
#   Condutividade Altura de chuva Vazão Temperatura  ...            V  \
# 1           6.9             NaN  0.18        14.9  ...   0.00242042
# 2           6.6             NaN  0.14        13.1  ...   0.00275178
# 3           7.2             NaN  0.09        12.5  ...   0.00176673
# 4           7.8             NaN  0.06        13.6  ...   0.00163148
# 5           7.9             NaN  0.05        14.3  ...  0.000588911
#
#            Zn          La          Ce           Pr           Sm           Eu  \
# 1  0.00214987  0.00157373  0.00269569  0.000334545  0.000117185  2.46111e-05
# 2   0.0432083  0.00197249  0.00295798  0.000417011  0.000207502  2.67827e-05
# 3   0.0393545   0.0016486  0.00254075  0.000333552  0.000226124   2.6322e-05
# 4  0.00214987  0.00121241  0.00175433  0.000279687  8.55281e-05  1.78332e-05
# 5  0.00214987  0.00187178   0.0025693  0.000354842  0.000199521  6.58051e-06
#
#             Gd       Nd          Pb
# 1  0.000118092  0.24932     0.04425
# 2  0.000214372  0.20307     0.05465
# 3  0.000146264     0.18  0.00644777
# 4  0.000120763  0.13043  0.00644777
# 5  0.000127186     0.24  0.00644777
#
# [5 rows x 69 columns]

# %%
# criando os subgrupos de dados
# rios
rios = df.loc[df['Tipo'] == 'Fluvial']
rioSB = rios.loc[rios['Ponto'] == 'Soberbo']
rioBM = rios.loc[rios['Ponto'] == 'Bonfim']
rioSM = rios.loc[rios['Ponto'] == 'Santa Marta']

# chuva (pp1 e pp2)
chuva = df.loc[(df['Tipo'] == 'Pluvial_PP1') | (df['Tipo'] == 'Pluvial_PP2')]
chuvaSB = chuva.loc[(chuva['Ponto'] == 'Soberbo')]
chuvaBM = chuva.loc[(chuva['Ponto'] == 'Bonfim')]
chuvaSM = chuva.loc[(chuva['Ponto'] == 'Santa Marta')]
chuvaPS = chuva.loc[(chuva['Ponto'] == 'Pedra do Sino')]

# chuva (pp1)
pp1 = df.loc[df['Tipo'] == 'Pluvial_PP1']
pp1SB = pp1.loc[pp1['Ponto'] == 'Soberbo']
pp1BM = pp1.loc[pp1['Ponto'] == 'Bonfim']
pp1SM = pp1.loc[pp1['Ponto'] == 'Santa Marta']
pp1PS = pp1.loc[pp1['Ponto'] == 'Pedra do Sino']

# chuva (pp2)
pp2 = df.loc[df['Tipo'] == 'Pluvial_PP2']
pp2SB = pp2.loc[pp2['Ponto'] == 'Soberbo']
pp2BM = pp2.loc[pp2['Ponto'] == 'Bonfim']
pp2SM = pp2.loc[pp2['Ponto'] == 'Santa Marta']
pp2PS = pp2.loc[pp2['Ponto'] == 'Pedra do Sino']
